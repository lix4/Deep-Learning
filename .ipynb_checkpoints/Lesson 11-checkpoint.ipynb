# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('./Iris-cleaned.csv')

# %%
data.head()
# Out:
#    sepal length  sepal width  petal length  petal width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.dtypes
# Out:
# sepal length    float64
# sepal width     float64
# petal length    float64
# petal width     float64
# species          object
# dtype: object

# %%
data['species'] = data.species.astype('category')
data.dtypes
# Out:
# sepal length     float64
# sepal width      float64
# petal length     float64
# petal width      float64
# species         category
# dtype: object

# %%
features = data.iloc[:, 0:4]
species = pd.get_dummies(data.species)

# %%
features.head()
# Out:
#    sepal length  sepal width  petal length  petal width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
data.head(10)
# Out:
#    sepal length  sepal width  petal length  petal width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
data.species.value_counts()
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %%
species.head()
# Out:
#    setosa  versicolor  virginica
# 0       1           0          0
# 1       1           0          0
# 2       1           0          0
# 3       1           0          0
# 4       1           0          0

# %%
feature_s = (features - features.mean()) / features.std()

# %%
print(feature_s.shape)
print(species.shape)
# Out:
# (150, 4)
# (150, 3)

# %%
# x is not trainable, while w and b is trainable

x = tf.placeholder(dtype = 'float32',shape=[150,4])
y = tf.placeholder(dtype = 'float32', shape=[150,3])
w = tf.Variable(tf.truncated_normal([4,3], stddev=1))
b = tf.Variable(tf.truncated_normal([1,3], stddev=1))

# %%
y1 = tf.nn.softmax(tf.matmul(x, w) + b)
loss = tf.reduce_mean(tf.square(y - y1))

# %%
# define optimizer
# STEP_SIZE = 0.0001
optimizer = tf.train.AdamOptimizer().minimize(loss)
init = tf.global_variables_initializer()

# %%
sess = tf.Session()
MAXSTEPS = 200000
MOD=10000
#initialize all variables
sess.run(init)

# %%
for step in range(MAXSTEPS+1):
    (_, loss_opt) = sess.run([optimizer,loss],feed_dict={x: feature_s, y: species})
    if (step % MOD) == 0:
        print(step, loss_opt)
# Out:
# 0 0.391796
# 10000 0.0100198
# 20000 0.00806755
# 30000 0.00660535
# 40000 0.00567535
# 50000 0.00513035
# 60000 0.00481896
# 70000 0.00464485
# 80000 0.0045499
# 90000 0.00449917
# 100000 0.00447265
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-0f9b044e9a0c> in <module>()
#       1 for step in range(MAXSTEPS+1):
# ----> 2     (_, loss_opt) = sess.run([optimizer,loss],feed_dict={x: feature_s, y: species})
#       3     if (step % MOD) == 0:
#       4         print(step, loss_opt)
#       5
#
# d:\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# d:\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# d:\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# d:\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# d:\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
(yp) = sess.run(y1, feed_dict={x:feature_s})

# %%
yp
# Out:
# array([[  1.00000000e+00,   3.33903430e-21,   0.00000000e+00],
#        [  1.00000000e+00,   3.97460656e-13,   0.00000000e+00],
#        [  1.00000000e+00,   1.44780782e-26,   0.00000000e+00],
#        [  1.00000000e+00,   6.52303685e-29,   0.00000000e+00],
#        [  1.00000000e+00,   2.53379725e-28,   0.00000000e+00],
#        [  1.00000000e+00,   2.61843962e-21,   0.00000000e+00],
#        [  1.00000000e+00,   4.77130101e-36,   0.00000000e+00],
#        [  1.00000000e+00,   9.51673213e-23,   0.00000000e+00],
#        [  1.00000000e+00,   1.34126606e-29,   0.00000000e+00],
#        [  1.00000000e+00,   9.62687479e-19,   0.00000000e+00],
   1.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   1.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   1.00000000e+00],
#        [  0.00000000e+00,   1.13198795e-27,   1.00000000e+00],
#        [  7.92378407e-32,   3.46928574e-02,   9.65307176e-01],
#        [  0.00000000e+00,   6.38722841e-32,   1.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   1.00000000e+00],
#        [  0.00000000e+00,   8.86753613e-28,   1.00000000e+00],
#        [  0.00000000e+00,   8.17373455e-29,   1.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   1.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   1.00000000e+00],
#        [  0.00000000e+00,   1.55525529e-36,   1.00000000e+00],
#        [  0.00000000e+00,   8.78315839e-23,   1.00000000e+00],
#        [  0.00000000e+00,   1.94126678e-24,   1.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   1.00000000e+00],
#        [  0.00000000e+00,   6.15203471e-17,   1.00000000e+00]], dtype=float32)

# %%
species.var().mean()
# Out:
# 0.22371364653243822

# %%
err=(yp.argmax(axis=1) != species.values.argmax(axis=1)).sum()

# %%
yp.argmax(axis=1) != species.values.argmax(axis=1)
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False], dtype=bool)

# %%
err = err / species.shape[0]
print("error_rate: ", err)
# Out:
# error_rate:  0.00666666666667

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Out:
#      setosa  versicolor  virginica
# 0         1           0          0
# 1         1           0          0
# 2         1           0          0
# 3         1           0          0
# 4         1           0          0
# 5         1           0          0
# 6         1           0          0
# 7         1           0          0
# 8         1           0          0
# 9         1           0          0
# 10        1           0          0
# 11        1           0          0
# 12        1           0          0
# 13        1           0          0
# 14        1           0          0
# 15        1           0          0
# 16        1           0          0
# 17        1           0          0
# 18        1           0          0
# 19        1           0          0
# 20        1           0          0
# 21        1           0          0
# 22        1           0          0
# 23        1           0          0
# 24        1           0          0
# 25        1           0          0
# 26        1           0          0
# 27        1           0          0
# 28        1           0          0
# 29        1           0          0
# ..      ...         ...        ...
# 120       0           0          1
# 121       0           0          1
# 122       0           0          1
# 123       0           0          1
# 124       0           0          1
# 125       0           0          1
# 126       0           0          1
# 127       0           0          1
# 128       0           0          1
# 129       0           0          1
# 130       0           0          1
# 131       0           0          1
# 132       0           0          1
# 133       0           0          1
# 134       0           0          1
# 135       0           0          1
# 136       0           0          1
# 137       0           0          1
# 138       0           0          1
# 139       0           0          1
# 140       0           0          1
# 141       0           0          1
# 142       0           0          1
# 143       0           0          1
# 144       0           0          1
# 145       0           0          1
# 146       0           0          1
# 147       0           0          1
# 148       0           0          1
# 149       0           0          1
#
# [150 rows x 3 columns]

# %%
LR = LogisticRegression(solver='sag', max_iter=100, random_state=42,
                             multi_class=multi_class)
print(species.shape)
LR.fit(feature_s, species)

species_pred = LR.predict(feature_s)

mse = ((species - species_pred) ** 2).mean()
print(mse)
# Out:
# (150, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-0866a0695746> in <module>()
#       1 LR = LogisticRegression(solver='sag', max_iter=100, random_state=42)
#       2 print(species.shape)
# ----> 3 LR.fit(feature_s, species)
#       4
#       5 species_pred = LR.predict(feature_s)
#
# d:\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1214
#    1215         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype,
# -> 1216                          order="C")
#    1217         check_classification_targets(y)
#    1218         self.classes_ = np.unique(y)
#
# d:\anaconda3\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     545                         dtype=None)
#     546     else:
# --> 547         y = column_or_1d(y, warn=True)
#     548         _assert_all_finite(y)
#     549     if y_numeric and y.dtype.kind == 'O':
#
# d:\anaconda3\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py in column_or_1d(y, warn)
#     581         return np.ravel(y)
#     582
# --> 583     raise ValueError("bad input shape {0}".format(shape))
#     584
#     585
#
# ValueError: bad input shape (150, 3)
