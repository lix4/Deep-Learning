# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
def soft_max(x):
    xmax = x.max()
    exp_x = np.exp(x - xmax)
    y = exp_x / exp_x.sum()
    return y

def mse(x,y):
    return ((x-y) ** 2).mean()

def ce(p,q):
    return -(p*np.log(q)).sum()

# %%
p = soft_max(np.random.rand(3))

# %%
q = soft_max(np.random.rand(3))

# %%
p.sum()
# Out:
# 1.0

# %%
mse(p,q)
# Out:
# 0.021217682535323367

# %%
ce(p,q)
# Out:
# 1.1782154742827018

# %%
n = 3 
N = 1000
A = 10
m = np.zeros(N)
c = np.zeros(N)

# %%
for k in range(1000):
    p = soft_max(A*np.random.rand(n))
    q = soft_max(A*np.random.rand(n))
    m[k] = mse(p,q)
    c[k] = ce(p,q)

# %%
plt.scatter(x=m,y=c,s=50,alpha=0.1)
plt.xlabel('MSE')
plt.ylabel('CE')
